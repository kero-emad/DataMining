# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('survey_results_public_after_cleaning.csv')

# %%
###### the problem is column check have one value only
df['Check'].unique()
# Out:
# array(['Apples'], dtype=object)

# %%
df=df.drop(columns=['Check'])

# %%
###### The problem is ResponseId column has many values  
df['ResponseId'].unique()
# Out:
# array([    1,     2,     3, ..., 65435, 65436, 65437], dtype=int64)

# %%
df=df.drop(columns=['ResponseId'])

# %%
x=df.drop('MainBranch',axis=1)
y=df['MainBranch']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.12, random_state=42)

# %%
x_train
# Out:
#                      Age                                         Employment  \
# 22896    45-54 years old                                Employed, full-time
# 61562    25-34 years old  Not employed, but looking for work;Independent...
# 24867  65 years or older                                            Retired
# 19387    25-34 years old                                Employed, full-time
# 63596    25-34 years old                                Employed, full-time
# ...                  ...                                                ...
# 62570    25-34 years old                                Employed, full-time
# 38158    55-64 years old                                Employed, full-time
# 860      35-44 years old                                Employed, full-time
# 15795    18-24 years old                                 Student, full-time
# 56422    18-24 years old                                Employed, full-time
#
#                                  RemoteWork  \
# ...

# %%
x_train.shape
# Out:
# (57584, 65)

# %%
x_test
# Out:
#                    Age                                         Employment  \
# 36662  18-24 years old                                I prefer not to say
# 36720  25-34 years old                                Employed, full-time
# 30718  25-34 years old                                Employed, full-time
# 17353  35-44 years old  Independent contractor, freelancer, or self-em...
# 39838  35-44 years old                                Employed, full-time
# ...                ...                                                ...
# 52226  18-24 years old             Student, part-time;Employed, part-time
# 23967  35-44 years old                                Employed, full-time
# 56220  25-34 years old  Employed, full-time;Independent contractor, fr...
# 36305  35-44 years old                                Employed, full-time
# 39814  25-34 years old  Employed, full-time;Independent contractor, fr...
#
#                                  RemoteWork  \
# ...

# %%
x_test.shape
# Out:
# (7853, 65)

# %%
##what are the most common technical branches (MainBranch) where people work remotely (RemoteWork) ??
result = df.groupby('RemoteWork')['MainBranch'].value_counts()
result
# Out:
# RemoteWork                            MainBranch
# Hybrid (some remote, some in-person)  I am a developer by profession                                                           22751
#                                       I am not primarily a developer, but I write code sometimes as part of my work/studies     4002
#                                       I am learning to code                                                                     3198
#                                       I code primarily as a hobby                                                               2732
#                                       I used to be a developer by profession, but no longer am                                   963
# In-person                             I am a developer by profession                                                            8697
#                                       I am not primarily a developer, but I write code sometimes as part of my work/studies     1289
# ...

# %%
##what is the distrubtion of the number of programmers based on industry (Tbranch) and educationlevel (ED level)?
result = df.groupby(['TBranch', 'EdLevel']).size().reset_index(name='Count')
result
# Out:
#    TBranch                                            EdLevel  Count
# 0       No                Associate degree (A.A., A.S., etc.)    409
# 1       No       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   6170
# 2       No    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   4445
# 3       No                          Primary/elementary school     77
# 4       No     Professional degree (JD, MD, Ph.D, Ed.D, etc.)    948
# 5       No  Secondary school (e.g. American high school, G...    732
# 6       No  Some college/university study without earning ...   1576
# 7       No                                     Something else    160
# 8      Yes                Associate degree (A.A., A.S., etc.)   1384
# 9      Yes       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  23425
# 10     Yes    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11112
# 11     Yes                          Primary/elementary school   1069
# 12     Yes     Professional degree (JD, MD, Ph.D, Ed.D, etc.)   2022
# ...

# %%
#what are the most commonly used prog. language (Language have worked with) in each age range (age)
result = df.groupby('Age')['AIToolCurrently Using'].value_counts()
print(result)
# Out:
# Age                 AIToolCurrently Using
# 18-24 years old     Writing code;Debugging and getting help;Search for answers                                         6343
#                     Writing code                                                                                        327
#                     Writing code;Debugging and getting help;Search for answers;Generating content or synthetic data     255
#                     Writing code;Search for answers                                                                     240
#                     Learning about a codebase;Writing code;Debugging and getting help;Search for answers                212
#                                                                                                                        ...
# Under 18 years old  Writing code;Search for answers;Other (please specify):                                               1
# ...

# %%
##what is number of people working remotely in each employment status??
result = df.groupby('Employment')['RemoteWork'].value_counts()
result
# Out:
# Employment                               RemoteWork
# Employed, full-time                      Hybrid (some remote, some in-person)    17296
#                                          Remote                                  13193
#                                          In-person                                8552
# Employed, full-time;Employed, part-time  Remote                                     95
#                                          Hybrid (some remote, some in-person)       85
#                                                                                  ...
# Student, part-time                       Hybrid (some remote, some in-person)      494
# Student, part-time;Employed, part-time   Hybrid (some remote, some in-person)      282
#                                          In-person                                 179
#                                          Remote                                     97
# ...

# %%
#what is the most common education level (edlevel) among employees ?
result = df['EdLevel'].value_counts()
result
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          29595
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15557
# Some college/university study without earning a degree                                 7651
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5793
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2970
# Associate degree (A.A., A.S., etc.)                                                    1793
# Primary/elementary school                                                              1146
# Something else                                                                          932
# Name: count, dtype: int64

# %%
#what is the most common working Type among employees ('RemoteWork') ?
result = df['RemoteWork'].value_counts()
result
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    33646
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %%
#What is the distribution of the number of programmers based on organization size (OrgSize) and BuildvsBuy?
result = df.groupby('OrgSize')['BuildvsBuy'].value_counts()
result
# Out:
# OrgSize                                             BuildvsBuy
# 1,000 to 4,999 employees                            Is ready-to-go but also customizable for growth and targeted use cases          3417
#                                                     Is set up to be customized and needs to be engineered into a usable product     1014
#                                                     Out-of-the-box is ready to go with little need for customization                 922
# 10 to 19 employees                                  Is ready-to-go but also customizable for growth and targeted use cases          2610
#                                                     Out-of-the-box is ready to go with little need for customization                 784
#                                                     Is set up to be customized and needs to be engineered into a usable product      690
# ...

# %%
#what is the most common education level (EdLevel) in each country ?
result = df.groupby('Country')['EdLevel'].value_counts()
result
# Out:
# Country      EdLevel
# Afghanistan  Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          20
#              Some college/university study without earning a degree                                10
#              Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        6
#              Primary/elementary school                                                              6
#              Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         4
#                                                                                                    ..
# Zimbabwe     Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          13
#              Some college/university study without earning a degree                                 6
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4
# ...

# %%
##what is the most common type of work (RemoteWork) for each range of age ?

result = df.groupby('Age')['RemoteWork'].value_counts()
result
# Out:
# Age                 RemoteWork
# 18-24 years old     Hybrid (some remote, some in-person)     8555
#                     In-person                                3034
#                     Remote                                   2509
# 25-34 years old     Hybrid (some remote, some in-person)    11330
#                     Remote                                   7984
#                     In-person                                4597
# 35-44 years old     Hybrid (some remote, some in-person)     6683
#                     Remote                                   6377
#                     In-person                                1882
# 45-54 years old     Hybrid (some remote, some in-person)     2870
#                     Remote                                   2520
#                     In-person                                 859
# 55-64 years old     Hybrid (some remote, some in-person)     1217
#                     Remote                                    992
# ...

# %%
###what is the most common ages for each work type (MainBranch) ?
result = df.groupby('MainBranch')['Age'].value_counts()
result
# Out:
# MainBranch                                                                             Age
# I am a developer by profession                                                         25-34 years old       20887
#                                                                                        35-44 years old       12705
#                                                                                        18-24 years old        9032
#                                                                                        45-54 years old        4937
#                                                                                        55-64 years old        1850
#                                                                                        65 years or older       353
#                                                                                        Under 18 years old      296
# ...

# %%
#What are the most common organization sizes (OrgSize) for each work type (MainBranch)?
result = df.groupby('MainBranch')['OrgSize'].value_counts()
result
# Out:
# MainBranch                                                                             OrgSize
# I am a developer by profession                                                         20 to 99 employees                                    17107
#                                                                                        100 to 499 employees                                   7984
#                                                                                        10,000 or more employees                               4905
#                                                                                        1,000 to 4,999 employees                               4740
#                                                                                        2 to 9 employees                                       4475
#                                                                                        10 to 19 employees                                     3821
# ...

# %%
#What are the most common levels of survey ease (SurveyEase) for each age group (Age)?
result = df.groupby('Age')['SurveyEase'].value_counts()
result
# Out:
# Age                 SurveyEase
# 18-24 years old     Easy                           8921
#                     Neither easy nor difficult     4860
#                     Difficult                       317
# 25-34 years old     Easy                          14135
#                     Neither easy nor difficult     9147
#                     Difficult                       629
# 35-44 years old     Easy                           8697
#                     Neither easy nor difficult     5851
#                     Difficult                       394
# 45-54 years old     Easy                           3609
#                     Neither easy nor difficult     2511
#                     Difficult                       129
# 55-64 years old     Easy                           1544
#                     Neither easy nor difficult      996
#                     Difficult                        35
# 65 years or older   Easy                            481
# ...

# %%
#What are the most common levels of survey length (SurveyLength) for each age group (Age)?
result = df.groupby('Age')['SurveyLength'].value_counts()
result
# Out:
# Age                 SurveyLength
# 18-24 years old     Appropriate in length    10805
#                     Too long                  3024
#                     Too short                  269
# 25-34 years old     Appropriate in length    17238
#                     Too long                  6377
#                     Too short                  296
# 35-44 years old     Appropriate in length    10567
#                     Too long                  4200
#                     Too short                  175
# 45-54 years old     Appropriate in length     4532
#                     Too long                  1660
#                     Too short                   57
# 55-64 years old     Appropriate in length     1972
#                     Too long                   586
#                     Too short                   17
# 65 years or older   Appropriate in length      624
#                     Too long                   143
#                     Too short                    5
# ...

# %%
##What are the most common survey lengths (SurveyLength) for each remote work type (RemoteWork)?
result = df.groupby('RemoteWork')['SurveyLength'].value_counts()
result
# Out:
# RemoteWork                            SurveyLength
# Hybrid (some remote, some in-person)  Appropriate in length    25125
#                                       Too long                  7972
#                                       Too short                  549
# In-person                             Appropriate in length     7915
#                                       Too long                  2933
#                                       Too short                  112
# Remote                                Appropriate in length    14982
#                                       Too long                  5601
#                                       Too short                  248
# Name: count, dtype: int64

# %%
##What are the most common purchase influence levels (PurchaseInfluence) for each education level (EdLevel)?
result = df.groupby('EdLevel')['PurchaseInfluence'].value_counts()
result
# Out:
# EdLevel                                                                             PurchaseInfluence
# Associate degree (A.A., A.S., etc.)                                                 I have some influence                 986
#                                                                                     I have little or no influence         494
#                                                                                     I have a great deal of influence      313
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                        I have some influence               17116
#                                                                                     I have little or no influence        8455
#                                                                                     I have a great deal of influence     4024
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                     I have some influence                7484
# ...

# %%
##What are the most common organization sizes (OrgSize) for each age group (Age)?
result = df.groupby('Age')['OrgSize'].value_counts()
result
# Out:
# Age                 OrgSize
# 18-24 years old     20 to 99 employees          8643
#                     100 to 499 employees        1134
#                     2 to 9 employees            1018
#                     10 to 19 employees           836
#                     10,000 or more employees     749
#                                                 ...
# Under 18 years old  1,000 to 4,999 employees       7
#                     100 to 499 employees           7
#                     500 to 999 employees           7
#                     10,000 or more employees       6
#                     5,000 to 9,999 employees       2
# Name: count, Length: 71, dtype: int64

# %%
#What are the most commonly used programming languages (LanguageHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['LanguageHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               LanguageHaveWorkedWith
# Academic researcher   HTML/CSS;JavaScript;TypeScript    56
#                       Python                            53
#                       Bash/Shell (all shells);Python    25
#                       Python;R                          15
#                       R                                 15
#                                                         ..
# System administrator  PowerShell;Python                  1
#                       PowerShell;Python;SQL              1
#                       Python;R                           1
#                       R                                  1
#                       SQL;VBA                            1
# Name: count, Length: 34096, dtype: int64

# %%
#What are the most commonly used databases (DatabaseHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['DatabaseHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               DatabaseHaveWorkedWith
# Academic researcher   PostgreSQL                          621
#                       SQLite                               81
#                       PostgreSQL;SQLite                    45
#                       MySQL                                30
#                       MySQL;SQLite                         24
#                                                          ...
# System administrator  MySQL;Redis                           1
#                       PostgreSQL;Redis                      1
#                       PostgreSQL;Redis;SQLite;Supabase      1
#                       Solr;SQLite                           1
#                       Supabase                              1
# Name: count, Length: 16715, dtype: int64

# %%
#What are the most commonly used platforms (PlatformHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['PlatformHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               PlatformHaveWorkedWith
# Academic researcher   Amazon Web Services (AWS)                 778
#                       Google Cloud                               52
#                       Microsoft Azure                            26
#                       Amazon Web Services (AWS);Google Cloud     20
#                       Hetzner                                    19
#                                                                ...
# System administrator  OpenStack;VMware                            1
#                       Oracle Cloud Infrastructure (OCI);OVH       1
#                       PythonAnywhere                              1
#                       Scaleway                                    1
#                       Supabase;Vercel                             1
# Name: count, Length: 11069, dtype: int64

# %%
#What are the most commonly used web frameworks (WebframeHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['WebframeHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               WebframeHaveWorkedWith
# Academic researcher   React                             706
#                       WordPress                          30
#                       Flask                              29
#                       Node.js                            25
#                       Django                             17
#                                                        ...
# System administrator  jQuery;Node.js;React;WordPress      1
#                       jQuery;Node.js;Symfony              1
#                       jQuery;Node.js;Vue.js               1
#                       jQuery;Node.js;Yii 2                1
#                       jQuery;Nuxt.js                      1
# Name: count, Length: 19573, dtype: int64

# %%
#What are the most commonly used miscellaneous technologies (MiscTechHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['MiscTechHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               MiscTechHaveWorkedWith
# Academic researcher   .NET (5+)                    325
#                       NumPy;Pandas                  46
#                       NumPy                         39
#                       Tidyverse                     37
#                       NumPy;Pandas;Scikit-Learn     22
#                                                   ...
# System administrator  Scikit-Learn                   1
#                       Spring Framework;Xamarin       1
#                       Tauri                          1
#                       Torch/PyTorch                  1
#                       Xamarin                        1
# Name: count, Length: 15052, dtype: int64

# %%
#What are the most commonly used tools (ToolsTechHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['ToolsTechHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               ToolsTechHaveWorkedWith
# Academic researcher   Docker                        337
#                       Pip                            79
#                       Make                           41
#                       Docker;Pip                     28
#                       Make;Pip                       24
#                                                    ...
# System administrator  npm;Pip;Vite;Webpack;Yarn       1
#                       npm;Unity 3D                    1
#                       npm;Webpack                     1
#                       npm;pnpm;Vite;Webpack;Yarn      1
#                       pnpm;Vite                       1
# Name: count, Length: 29191, dtype: int64

# %%
#What are the most commonly used collaboration tools (NEWCollabToolsHaveWorkedWith) by job type (DevType)?
result = df.groupby('DevType')['NEWCollabToolsHaveWorkedWith'].value_counts()
print(result)
# Out:
# DevType               NEWCollabToolsHaveWorkedWith
# Academic researcher   Visual Studio Code                                170
#                       Jupyter Notebook/JupyterLab;Visual Studio Code     28
#                       Vim                                                28
#                       Vim;Visual Studio Code                             23
#                       RStudio;Visual Studio Code                         20
#                                                                        ...
# System administrator  Spyder;Visual Studio                                1
#                       Vim;Visual Studio Code;VSCodium                     1
#                       Vim;Visual Studio;Visual Studio Code                1
#                       Vim;Xcode                                           1
#                       Xcode                                               1
# Name: count, Length: 23327, dtype: int64
